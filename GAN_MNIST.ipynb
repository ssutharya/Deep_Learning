# %% [markdown]
# Implement a Python program using PyTorch to build a Generative Adversarial Network (GAN) that generates handwritten digits based on the MNIST dataset.

# %%
# %pip install torch torchvision matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 56.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
import torch
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

# convert the images to tensors and normalize them
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

batch_size = 128
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)

print(f"Number of training samples: {len(train_dataset)}")
print(f"Number of batches in training loader: {len(train_loader)}")
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 17.9MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 478kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.45MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.15MB/s]
# Number of training samples: 60000
# Number of batches in training loader: 469

# %%
import torch.nn as nn

class Generator(nn.Module):
    def __init__(self, latent_dim, img_shape):
        super().__init__()
        self.img_shape = img_shape

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(128, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, int(torch.prod(torch.tensor(img_shape)))),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        img = img.view(img.size(0), *self.img_shape)
        return img

# testing
latent_dim = 100
img_shape = (1, 28, 28)
generator = Generator(latent_dim, img_shape)
print(generator)
# Out:
# Generator(
#   (model): Sequential(
#     (0): Linear(in_features=100, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Linear(in_features=256, out_features=512, bias=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#     (6): Linear(in_features=512, out_features=784, bias=True)
#     (7): Tanh()
#   )
# )

# %%
import torch.nn as nn

class Discriminator(nn.Module):
    def __init__(self, img_shape):
        super().__init__()
        self.img_shape = img_shape

        self.model = nn.Sequential(
            nn.Linear(int(torch.prod(torch.tensor(img_shape))), 512),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid() # using Sigmoid for binary classification output
        )

    def forward(self, img):
        img_flat = img.view(img.size(0), -1)
        validity = self.model(img_flat)
        return validity

# testing
img_shape = (1, 28, 28)
discriminator = Discriminator(img_shape)
print(discriminator)
# Out:
# Discriminator(
#   (model): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Linear(in_features=256, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )

# %%
import torch.optim as optim
import torch.nn as nn

adversarial_loss = nn.BCELoss()

learning_rate = 0.0002
beta1 = 0.5
beta2 = 0.999
optimizer_g = optim.Adam(generator.parameters(), lr=learning_rate, betas=(beta1, beta2))

optimizer_d = optim.Adam(discriminator.parameters(), lr=learning_rate, betas=(beta1, beta2))

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

generator.to(device)
discriminator.to(device)

num_epochs = 50

# training loop
print("Starting training loop...")
for epoch in range(num_epochs):
    for i, (imgs, _) in enumerate(train_loader):

        real_imgs = imgs.to(device)
        real_labels = torch.ones(imgs.size(0), 1).to(device)
        fake_labels = torch.zeros(imgs.size(0), 1).to(device)

        optimizer_d.zero_grad()

        real_output = discriminator(real_imgs)
        d_loss_real = adversarial_loss(real_output, real_labels)

        z = torch.randn(imgs.size(0), latent_dim).to(device)
        fake_imgs = generator(z).detach()

        fake_output = discriminator(fake_imgs)
        d_loss_fake = adversarial_loss(fake_output, fake_labels)

        d_loss = (d_loss_real + d_loss_fake) / 2

        d_loss.backward()
        optimizer_d.step()

        optimizer_g.zero_grad()

        z = torch.randn(imgs.size(0), latent_dim).to(device)
        fake_imgs = generator(z)

        g_loss = adversarial_loss(discriminator(fake_imgs), real_labels)

        g_loss.backward()
        optimizer_g.step()

        if (i + 1) % 100 == 0:
            print(
                f"[Epoch {epoch}/{num_epochs}] [Batch {i+1}/{len(train_loader)}] "
                f"[D loss: {d_loss.item():.4f}] [G loss: {g_loss.item():.4f}]"
            )

    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(25, latent_dim).to(device)
            generated_images = generator(z).cpu()
            print(f"Epoch {epoch+1}: Generated sample images.")

print("Training finished.")
# Out:
# Using device: cuda
# Starting training loop...
# [Epoch 0/50] [Batch 100/469] [D loss: 0.4568] [G loss: 1.0560]
# [Epoch 0/50] [Batch 200/469] [D loss: 0.5748] [G loss: 1.1134]
# [Epoch 0/50] [Batch 300/469] [D loss: 0.4246] [G loss: 1.3317]
# [Epoch 0/50] [Batch 400/469] [D loss: 0.3922] [G loss: 2.4861]
# [Epoch 1/50] [Batch 100/469] [D loss: 0.1395] [G loss: 2.9832]
# [Epoch 1/50] [Batch 200/469] [D loss: 0.2838] [G loss: 4.6163]
# [Epoch 1/50] [Batch 300/469] [D loss: 1.2283] [G loss: 4.0731]
# [Epoch 1/50] [Batch 400/469] [D loss: 0.4097] [G loss: 5.0853]
# [Epoch 2/50] [Batch 100/469] [D loss: 0.1664] [G loss: 3.4983]
# [Epoch 2/50] [Batch 200/469] [D loss: 0.2236] [G loss: 2.0402]
# [Epoch 2/50] [Batch 300/469] [D loss: 0.8659] [G loss: 1.3896]
# [Epoch 2/50] [Batch 400/469] [D loss: 0.2060] [G loss: 2.6752]
# [Epoch 3/50] [Batch 100/469] [D loss: 0.3552] [G loss: 1.1571]
# [Epoch 3/50] [Batch 200/469] [D loss: 0.1631] [G loss: 1.7358]
# [Epoch 3/50] [Batch 300/469] [D loss: 0.2190] [G loss: 3.2212]
# [Epoch 3/50] [Batch 400/469] [D loss: 0.1837] [G loss: 3.6638]
# [Epoch 4/50] [Batch 100/469] [D loss: 0.2882] [G loss: 1.3598]
# [Epoch 4/50] [Batch 200/469] [D loss: 0.2260] [G loss: 1.9422]
# [Epoch 4/50] [Batch 300/469] [D loss: 0.1473] [G loss: 3.1642]
# [Epoch 4/50] [Batch 400/469] [D loss: 0.3527] [G loss: 2.5897]
# [Epoch 5/50] [Batch 100/469] [D loss: 0.2517] [G loss: 2.0853]
# [Epoch 5/50] [Batch 200/469] [D loss: 0.1728] [G loss: 4.0721]
# [Epoch 5/50] [Batch 300/469] [D loss: 0.1399] [G loss: 3.6523]
# [Epoch 5/50] [Batch 400/469] [D loss: 0.3485] [G loss: 5.2258]
# [Epoch 6/50] [Batch 100/469] [D loss: 0.1559] [G loss: 3.6226]
# [Epoch 6/50] [Batch 200/469] [D loss: 0.1561] [G loss: 2.9305]
# [Epoch 6/50] [Batch 300/469] [D loss: 0.1835] [G loss: 3.5126]
# [Epoch 6/50] [Batch 400/469] [D loss: 0.1895] [G loss: 2.6143]
# [Epoch 7/50] [Batch 100/469] [D loss: 0.4265] [G loss: 4.9886]
# [Epoch 7/50] [Batch 200/469] [D loss: 0.1468] [G loss: 1.4812]
# [Epoch 7/50] [Batch 300/469] [D loss: 0.3810] [G loss: 4.9756]
# [Epoch 7/50] [Batch 400/469] [D loss: 0.1661] [G loss: 2.6505]
# [Epoch 8/50] [Batch 100/469] [D loss: 0.4753] [G loss: 0.8796]
# [Epoch 8/50] [Batch 200/469] [D loss: 0.2126] [G loss: 1.3948]
# [Epoch 8/50] [Batch 300/469] [D loss: 0.2247] [G loss: 1.7266]
# [Epoch 8/50] [Batch 400/469] [D loss: 0.1652] [G loss: 2.9489]
# [Epoch 9/50] [Batch 100/469] [D loss: 0.1712] [G loss: 3.2425]
# [Epoch 9/50] [Batch 200/469] [D loss: 0.5523] [G loss: 4.0120]
# [Epoch 9/50] [Batch 300/469] [D loss: 0.1876] [G loss: 2.3984]
# [Epoch 9/50] [Batch 400/469] [D loss: 0.4578] [G loss: 1.9225]
# Epoch 10: Generated sample images.
# [Epoch 10/50] [Batch 100/469] [D loss: 0.2328] [G loss: 2.6898]
# [Epoch 10/50] [Batch 200/469] [D loss: 0.3066] [G loss: 2.4592]
# [Epoch 10/50] [Batch 300/469] [D loss: 0.3131] [G loss: 1.8883]
# [Epoch 10/50] [Batch 400/469] [D loss: 0.2276] [G loss: 2.1797]
# [Epoch 11/50] [Batch 100/469] [D loss: 0.2334] [G loss: 2.2263]
# [Epoch 11/50] [Batch 200/469] [D loss: 0.6277] [G loss: 0.8074]
# [Epoch 11/50] [Batch 300/469] [D loss: 0.5229] [G loss: 0.8630]
# [Epoch 11/50] [Batch 400/469] [D loss: 0.9256] [G loss: 0.8263]
# [Epoch 12/50] [Batch 100/469] [D loss: 0.3141] [G loss: 2.8765]
# [Epoch 12/50] [Batch 200/469] [D loss: 0.3446] [G loss: 2.4010]
# [Epoch 12/50] [Batch 300/469] [D loss: 0.3974] [G loss: 2.2081]
# [Epoch 12/50] [Batch 400/469] [D loss: 0.2648] [G loss: 1.4739]
# [Epoch 13/50] [Batch 100/469] [D loss: 0.7862] [G loss: 1.5078]
# [Epoch 13/50] [Batch 200/469] [D loss: 0.3063] [G loss: 1.3409]
# [Epoch 13/50] [Batch 300/469] [D loss: 0.3327] [G loss: 1.2901]
# [Epoch 13/50] [Batch 400/469] [D loss: 0.4286] [G loss: 3.8421]
# [Epoch 14/50] [Batch 100/469] [D loss: 0.3520] [G loss: 1.2588]
# [Epoch 14/50] [Batch 200/469] [D loss: 0.3422] [G loss: 1.1948]
# [Epoch 14/50] [Batch 300/469] [D loss: 0.3868] [G loss: 1.4154]
# [Epoch 14/50] [Batch 400/469] [D loss: 0.3263] [G loss: 1.7911]
# [Epoch 15/50] [Batch 100/469] [D loss: 0.3834] [G loss: 1.3167]
# [Epoch 15/50] [Batch 200/469] [D loss: 0.3599] [G loss: 1.3731]
# [Epoch 15/50] [Batch 300/469] [D loss: 0.3484] [G loss: 1.5074]
# [Epoch 15/50] [Batch 400/469] [D loss: 0.4213] [G loss: 1.0181]
# [Epoch 16/50] [Batch 100/469] [D loss: 0.3910] [G loss: 1.5328]
# [Epoch 16/50] [Batch 200/469] [D loss: 0.4264] [G loss: 1.9675]
# [Epoch 16/50] [Batch 300/469] [D loss: 0.5537] [G loss: 0.9291]
# [Epoch 16/50] [Batch 400/469] [D loss: 0.5263] [G loss: 0.7358]
# [Epoch 17/50] [Batch 100/469] [D loss: 0.4919] [G loss: 2.7233]
# [Epoch 17/50] [Batch 200/469] [D loss: 0.5935] [G loss: 2.8777]
# [Epoch 17/50] [Batch 300/469] [D loss: 0.6014] [G loss: 0.4569]
# [Epoch 17/50] [Batch 400/469] [D loss: 0.4067] [G loss: 1.5065]
# [Epoch 18/50] [Batch 100/469] [D loss: 0.5934] [G loss: 2.5572]
# [Epoch 18/50] [Batch 200/469] [D loss: 0.4421] [G loss: 1.4235]
# [Epoch 18/50] [Batch 300/469] [D loss: 0.8438] [G loss: 3.1375]
# [Epoch 18/50] [Batch 400/469] [D loss: 0.4540] [G loss: 1.4612]
# [Epoch 19/50] [Batch 100/469] [D loss: 0.5113] [G loss: 2.0583]
# [Epoch 19/50] [Batch 200/469] [D loss: 0.4713] [G loss: 2.0083]
# [Epoch 19/50] [Batch 300/469] [D loss: 0.3737] [G loss: 1.7155]
# [Epoch 19/50] [Batch 400/469] [D loss: 0.6050] [G loss: 1.7244]
# Epoch 20: Generated sample images.
# [Epoch 20/50] [Batch 100/469] [D loss: 0.5345] [G loss: 1.9218]
# [Epoch 20/50] [Batch 200/469] [D loss: 0.4982] [G loss: 1.6476]
# [Epoch 20/50] [Batch 300/469] [D loss: 0.4855] [G loss: 1.2931]
# [Epoch 20/50] [Batch 400/469] [D loss: 0.4667] [G loss: 1.6177]
# [Epoch 21/50] [Batch 100/469] [D loss: 0.4546] [G loss: 1.4709]
# [Epoch 21/50] [Batch 200/469] [D loss: 0.4431] [G loss: 1.4767]
# [Epoch 21/50] [Batch 300/469] [D loss: 0.8128] [G loss: 2.6244]
# [Epoch 21/50] [Batch 400/469] [D loss: 0.4886] [G loss: 2.2935]
# [Epoch 22/50] [Batch 100/469] [D loss: 0.5419] [G loss: 1.6201]
# [Epoch 22/50] [Batch 200/469] [D loss: 0.4687] [G loss: 1.3770]
# [Epoch 22/50] [Batch 300/469] [D loss: 0.4453] [G loss: 1.5472]
# [Epoch 22/50] [Batch 400/469] [D loss: 0.5583] [G loss: 2.1855]
# [Epoch 23/50] [Batch 100/469] [D loss: 0.4641] [G loss: 1.1547]
# [Epoch 23/50] [Batch 200/469] [D loss: 0.5477] [G loss: 0.6839]
# [Epoch 23/50] [Batch 300/469] [D loss: 0.5162] [G loss: 1.5575]
# [Epoch 23/50] [Batch 400/469] [D loss: 0.5645] [G loss: 0.8389]
# [Epoch 24/50] [Batch 100/469] [D loss: 0.4957] [G loss: 0.9594]
# [Epoch 24/50] [Batch 200/469] [D loss: 0.5263] [G loss: 0.9053]
# [Epoch 24/50] [Batch 300/469] [D loss: 0.5035] [G loss: 1.9951]
# [Epoch 24/50] [Batch 400/469] [D loss: 0.5390] [G loss: 0.7357]
# [Epoch 25/50] [Batch 100/469] [D loss: 0.5161] [G loss: 1.9273]
# [Epoch 25/50] [Batch 200/469] [D loss: 0.4888] [G loss: 1.5750]
# [Epoch 25/50] [Batch 300/469] [D loss: 0.4809] [G loss: 0.9397]
# [Epoch 25/50] [Batch 400/469] [D loss: 0.5141] [G loss: 0.9805]
# [Epoch 26/50] [Batch 100/469] [D loss: 0.4520] [G loss: 1.2640]
# [Epoch 26/50] [Batch 200/469] [D loss: 0.5352] [G loss: 0.9341]
# [Epoch 26/50] [Batch 300/469] [D loss: 0.5464] [G loss: 1.1249]
# [Epoch 26/50] [Batch 400/469] [D loss: 0.4673] [G loss: 0.9429]
# [Epoch 27/50] [Batch 100/469] [D loss: 0.5270] [G loss: 0.9223]
# [Epoch 27/50] [Batch 200/469] [D loss: 0.6925] [G loss: 0.6626]
# [Epoch 27/50] [Batch 300/469] [D loss: 0.4853] [G loss: 0.8812]
# [Epoch 27/50] [Batch 400/469] [D loss: 0.5699] [G loss: 0.5653]
# [Epoch 28/50] [Batch 100/469] [D loss: 0.4423] [G loss: 1.0056]
# [Epoch 28/50] [Batch 200/469] [D loss: 0.6210] [G loss: 0.6413]
# [Epoch 28/50] [Batch 300/469] [D loss: 0.5176] [G loss: 0.9648]
# [Epoch 28/50] [Batch 400/469] [D loss: 0.5494] [G loss: 0.6864]
# [Epoch 29/50] [Batch 100/469] [D loss: 0.4723] [G loss: 0.9841]
# [Epoch 29/50] [Batch 200/469] [D loss: 0.4870] [G loss: 1.3579]
# [Epoch 29/50] [Batch 300/469] [D loss: 0.5311] [G loss: 0.6786]
# [Epoch 29/50] [Batch 400/469] [D loss: 0.4470] [G loss: 1.4098]
# Epoch 30: Generated sample images.
# [Epoch 30/50] [Batch 100/469] [D loss: 0.4793] [G loss: 1.0233]
# [Epoch 30/50] [Batch 200/469] [D loss: 0.4883] [G loss: 0.8930]
# [Epoch 30/50] [Batch 300/469] [D loss: 0.4553] [G loss: 1.3451]
# [Epoch 30/50] [Batch 400/469] [D loss: 0.5320] [G loss: 1.6001]
# [Epoch 31/50] [Batch 100/469] [D loss: 0.4689] [G loss: 1.3646]
# [Epoch 31/50] [Batch 200/469] [D loss: 0.4966] [G loss: 0.9930]
# [Epoch 31/50] [Batch 300/469] [D loss: 0.5662] [G loss: 1.9122]
# [Epoch 31/50] [Batch 400/469] [D loss: 0.5667] [G loss: 1.7635]
# [Epoch 32/50] [Batch 100/469] [D loss: 0.5050] [G loss: 1.2401]
# [Epoch 32/50] [Batch 200/469] [D loss: 0.4931] [G loss: 0.9018]
# [Epoch 32/50] [Batch 300/469] [D loss: 0.5296] [G loss: 1.8625]
# [Epoch 32/50] [Batch 400/469] [D loss: 0.6178] [G loss: 0.5326]
# [Epoch 33/50] [Batch 100/469] [D loss: 0.4846] [G loss: 0.8837]
# [Epoch 33/50] [Batch 200/469] [D loss: 0.4961] [G loss: 1.1225]
# [Epoch 33/50] [Batch 300/469] [D loss: 0.4581] [G loss: 1.0320]
# [Epoch 33/50] [Batch 400/469] [D loss: 0.5218] [G loss: 1.1579]
# [Epoch 34/50] [Batch 100/469] [D loss: 0.4591] [G loss: 1.0971]
# [Epoch 34/50] [Batch 200/469] [D loss: 0.5009] [G loss: 0.8360]
# [Epoch 34/50] [Batch 300/469] [D loss: 0.5147] [G loss: 0.8837]
# [Epoch 34/50] [Batch 400/469] [D loss: 0.4449] [G loss: 1.2487]
# [Epoch 35/50] [Batch 100/469] [D loss: 0.5879] [G loss: 1.7761]
# [Epoch 35/50] [Batch 200/469] [D loss: 0.5618] [G loss: 1.6186]
# [Epoch 35/50] [Batch 300/469] [D loss: 0.5516] [G loss: 2.0289]
# [Epoch 35/50] [Batch 400/469] [D loss: 0.5021] [G loss: 1.6400]
# [Epoch 36/50] [Batch 100/469] [D loss: 0.5169] [G loss: 1.0683]
# [Epoch 36/50] [Batch 200/469] [D loss: 0.8224] [G loss: 2.1906]
# [Epoch 36/50] [Batch 300/469] [D loss: 0.5489] [G loss: 1.4667]
# [Epoch 36/50] [Batch 400/469] [D loss: 0.5075] [G loss: 0.7850]
# [Epoch 37/50] [Batch 100/469] [D loss: 0.4989] [G loss: 1.1827]
# [Epoch 37/50] [Batch 200/469] [D loss: 0.5204] [G loss: 1.0243]
# [Epoch 37/50] [Batch 300/469] [D loss: 0.5079] [G loss: 1.1966]
# [Epoch 37/50] [Batch 400/469] [D loss: 0.4548] [G loss: 1.3485]
# [Epoch 38/50] [Batch 100/469] [D loss: 0.4594] [G loss: 0.9079]
# [Epoch 38/50] [Batch 200/469] [D loss: 0.5081] [G loss: 1.1395]
# [Epoch 38/50] [Batch 300/469] [D loss: 0.4881] [G loss: 0.8620]
# [Epoch 38/50] [Batch 400/469] [D loss: 0.5850] [G loss: 1.7960]
# [Epoch 39/50] [Batch 100/469] [D loss: 0.5655] [G loss: 0.6083]
# [Epoch 39/50] [Batch 200/469] [D loss: 0.4956] [G loss: 0.9605]
# [Epoch 39/50] [Batch 300/469] [D loss: 0.5156] [G loss: 1.3635]
# [Epoch 39/50] [Batch 400/469] [D loss: 0.4522] [G loss: 1.2714]
# Epoch 40: Generated sample images.
# [Epoch 40/50] [Batch 100/469] [D loss: 0.4772] [G loss: 1.1975]
# [Epoch 40/50] [Batch 200/469] [D loss: 0.5307] [G loss: 1.8210]
# [Epoch 40/50] [Batch 300/469] [D loss: 0.4801] [G loss: 1.0683]
# [Epoch 40/50] [Batch 400/469] [D loss: 0.6105] [G loss: 0.6477]
# [Epoch 41/50] [Batch 100/469] [D loss: 0.5121] [G loss: 1.8376]
# [Epoch 41/50] [Batch 200/469] [D loss: 0.4509] [G loss: 1.2649]
# [Epoch 41/50] [Batch 300/469] [D loss: 0.6727] [G loss: 0.5825]
# [Epoch 41/50] [Batch 400/469] [D loss: 0.5025] [G loss: 1.1307]
# [Epoch 42/50] [Batch 100/469] [D loss: 0.4873] [G loss: 1.6516]
# [Epoch 42/50] [Batch 200/469] [D loss: 0.5083] [G loss: 1.4141]
# [Epoch 42/50] [Batch 300/469] [D loss: 0.4663] [G loss: 1.1374]
# [Epoch 42/50] [Batch 400/469] [D loss: 0.4562] [G loss: 1.4567]
# [Epoch 43/50] [Batch 100/469] [D loss: 0.4915] [G loss: 1.3974]
# [Epoch 43/50] [Batch 200/469] [D loss: 0.4784] [G loss: 1.3855]
# [Epoch 43/50] [Batch 300/469] [D loss: 0.5245] [G loss: 0.8063]
# [Epoch 43/50] [Batch 400/469] [D loss: 0.5958] [G loss: 2.2390]
# [Epoch 44/50] [Batch 100/469] [D loss: 0.5456] [G loss: 0.9281]
# [Epoch 44/50] [Batch 200/469] [D loss: 0.4835] [G loss: 1.2220]
# [Epoch 44/50] [Batch 300/469] [D loss: 0.5023] [G loss: 0.6969]
# [Epoch 44/50] [Batch 400/469] [D loss: 0.4809] [G loss: 1.5270]
# [Epoch 45/50] [Batch 100/469] [D loss: 0.5169] [G loss: 1.1390]
# [Epoch 45/50] [Batch 200/469] [D loss: 0.5053] [G loss: 1.2188]
# [Epoch 45/50] [Batch 300/469] [D loss: 0.4994] [G loss: 0.8815]
# [Epoch 45/50] [Batch 400/469] [D loss: 0.4665] [G loss: 0.9197]
# [Epoch 46/50] [Batch 100/469] [D loss: 0.5188] [G loss: 0.9986]
# [Epoch 46/50] [Batch 200/469] [D loss: 0.4312] [G loss: 1.1805]
# [Epoch 46/50] [Batch 300/469] [D loss: 0.4775] [G loss: 0.9707]
# [Epoch 46/50] [Batch 400/469] [D loss: 0.4516] [G loss: 1.2059]
# [Epoch 47/50] [Batch 100/469] [D loss: 0.4863] [G loss: 1.0460]
# [Epoch 47/50] [Batch 200/469] [D loss: 0.4635] [G loss: 1.5457]
# [Epoch 47/50] [Batch 300/469] [D loss: 0.4734] [G loss: 1.6440]
# [Epoch 47/50] [Batch 400/469] [D loss: 0.4978] [G loss: 1.1015]
# [Epoch 48/50] [Batch 100/469] [D loss: 0.5733] [G loss: 1.7601]
# [Epoch 48/50] [Batch 200/469] [D loss: 0.4979] [G loss: 1.2862]
# [Epoch 48/50] [Batch 300/469] [D loss: 0.4435] [G loss: 0.9739]
# [Epoch 48/50] [Batch 400/469] [D loss: 0.4994] [G loss: 1.1591]
# [Epoch 49/50] [Batch 100/469] [D loss: 0.4809] [G loss: 1.6328]
# [Epoch 49/50] [Batch 200/469] [D loss: 0.5092] [G loss: 1.4597]
# [Epoch 49/50] [Batch 300/469] [D loss: 0.4778] [G loss: 1.1978]
# [Epoch 49/50] [Batch 400/469] [D loss: 0.4577] [G loss: 1.1508]
# Epoch 50: Generated sample images.
# Training finished.

# %%
import matplotlib.pyplot as plt
import numpy as np

with torch.no_grad():
    z = torch.randn(25, latent_dim).to(device)
    generated_images = generator(z).cpu()

fig, axes = plt.subplots(5, 5, figsize=(8, 8))
for i, ax in enumerate(axes.flat):
    ax.imshow(np.squeeze(generated_images[i].permute(1, 2, 0).numpy()), cmap='gray')
    ax.axis('off')
plt.suptitle("Generated MNIST Digits")
plt.show()
